# %%
# !pip install PyMySql

# %%
# !pip install PyMySql

# %%
import pymysql

# %%
db = pymysql.connect(host='127.0.0.1',port=3306,user='jay',passwd='12345',db='w3schools',charset='utf8')

# %%
cursor = db.cursor()

# %%
sql = 'select * from customers'
cursor.execute(sql)
resultset = cursor.fetchall()
resultset
# Out:
# ((1,
#   'Alfreds Futterkiste',
#   'Maria Anders',
#   'Obere Str. 57',
#   'Berlin',
#   '12209',
#   'Germany'),
#  (2,
#   'Ana Trujillo Emparedados y helados',
#   'Ana Trujillo',
#   'Avda. de la Constitución 2222',
#   'México D.F.',
#   '05021',
#   'Mexico'),
#  (3,
#   'Antonio Moreno Taquería',
#   'Antonio Moreno',
#   'Mataderos 2312',
#   'México D.F.',
#   '05023',
#   'Mexico'),
#  (4,
#   'Around the Horn',
#   'Thomas Hardy',
#   '120 Hanover Sq.',
#   'London',
#   'WA1 1DP',
#   'UK'),
#  (5,
#   'Berglunds snabbköp',
#   'Christina Berglund',
#   'Berguvsvägen 8',
#   'Luleå',
#   'S-958 22',
#   'Sweden'),
#  (6,
#   'Blauer See Delikatessen',
#   'Hanna Moos',
#   'Forsterstr. 57',
#   'Mannheim',
#   '68306',
#   'Germany'),
#  (7,
#   'Blondel père et fils',
#   'Frédérique Citeaux',
#   '24, place Kléber',
#   'Strasbourg',
#   '67000',
#   'France'),
#  (8,
#   'Bólido Comidas preparadas',
#   'Martín Sommer',
#   'C/ Araquil, 67',
#   'Madrid',
# ...

# %%
for result in resultset:
    print(result)
# Out:
# (1, 'Alfreds Futterkiste', 'Maria Anders', 'Obere Str. 57', 'Berlin', '12209', 'Germany')
# (2, 'Ana Trujillo Emparedados y helados', 'Ana Trujillo', 'Avda. de la Constitución 2222', 'México D.F.', '05021', 'Mexico')
# (3, 'Antonio Moreno Taquería', 'Antonio Moreno', 'Mataderos 2312', 'México D.F.', '05023', 'Mexico')
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (5, 'Berglunds snabbköp', 'Christina Berglund', 'Berguvsvägen 8', 'Luleå', 'S-958 22', 'Sweden')
# (6, 'Blauer See Delikatessen', 'Hanna Moos', 'Forsterstr. 57', 'Mannheim', '68306', 'Germany')
# (7, 'Blondel père et fils', 'Frédérique Citeaux', '24, place Kléber', 'Strasbourg', '67000', 'France')
# (8, 'Bólido Comidas preparadas', 'Martín Sommer', 'C/ Araquil, 67', 'Madrid', '28023', 'Spain')
# (9, "Bon app'", 'Laurence Lebihans', '12, rue des Bouchers', 'Marseille', '13008', 'France')
# ...

# %%
cursor = db.cursor(pymysql.cursors.DictCursor)

# %%
sql = 'select * from customers'
cursor.execute(sql)
resultset = cursor.fetchall()
for result in resultset:
    print(result)
# Out:
# {'CustomerID': 1, 'CustomerName': 'Alfreds Futterkiste', 'ContactName': 'Maria Anders', 'Address': 'Obere Str. 57', 'City': 'Berlin', 'PostalCode': '12209', 'Country': 'Germany'}
# {'CustomerID': 2, 'CustomerName': 'Ana Trujillo Emparedados y helados', 'ContactName': 'Ana Trujillo', 'Address': 'Avda. de la Constitución 2222', 'City': 'México D.F.', 'PostalCode': '05021', 'Country': 'Mexico'}
# {'CustomerID': 3, 'CustomerName': 'Antonio Moreno Taquería', 'ContactName': 'Antonio Moreno', 'Address': 'Mataderos 2312', 'City': 'México D.F.', 'PostalCode': '05023', 'Country': 'Mexico'}
# {'CustomerID': 4, 'CustomerName': 'Around the Horn', 'ContactName': 'Thomas Hardy', 'Address': '120 Hanover Sq.', 'City': 'London', 'PostalCode': 'WA1 1DP', 'Country': 'UK'}
# {'CustomerID': 5, 'CustomerName': 'Berglunds snabbköp', 'ContactName': 'Christina Berglund', 'Address': 'Berguvsvägen 8', 'City': 'Luleå', 'PostalCode': 'S-958 22', 'Country': 'Sweden'}
# ...

# %%
cursor = db.cursor()

# %%
sql = 'select * from customers where country = %s'
cursor.execute(sql,'UK')
rs =cursor.fetchall()
for result in rs:
    print(result)
# Out:
# (4, 'Around the Horn', 'Thomas Hardy', '120 Hanover Sq.', 'London', 'WA1 1DP', 'UK')
# (11, "B's Beverages", 'Victoria Ashworth', 'Fauntleroy Circus', 'London', 'EC2 5NT', 'UK')
# (16, 'Consolidated Holdings', 'Elizabeth Brown', 'Berkeley Gardens 12 Brewery', 'London', 'WX1 6LT', 'UK')
# (19, 'Eastern Connection', 'Ann Devon', '35 King George', 'London', 'WX3 6FW', 'UK')
# (38, 'Island Trading', 'Helen Bennett', 'Garden House Crowther Way', 'Cowes', 'PO31 7PJ', 'UK')
# (53, 'North/South', 'Simon Crowther', 'South House 300 Queensbridge', 'London', 'SW7 1RZ', 'UK')
# (72, 'Seven Seas Imports', 'Hari Kumar', '90 Wadhurst Rd.', 'London', 'OX15 4NB', 'UK')

# %%
sql = 'select * from customers where country = %s'
cursor.execute(sql,'UK')
rs =cursor.fetchone()
for result in rs:
    print(result)
# Out:
# 4
# Around the Horn
# Thomas Hardy
# 120 Hanover Sq.
# London
# WA1 1DP
# UK

# %%
sql = '''
CREATE TABLE scores(
    name varchar(20) NOT NULL,
    math int,
    science int,
    english int,
    PRIMARY KEY (name)
    )
'''
cursor.execute(sql)
db.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-36-43f6c6c6f579> in <module>
#       8     )
#       9 '''
# ---> 10 cursor.execute(sql)
#      11 db.commit()
#
# ~\anaconda3\envs\study\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     161         query = self.mogrify(query, args)
#     162
# --> 163         result = self._query(query)
#     164         self._executed = query
#     165         return result
#
# ~\anaconda3\envs\study\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     319         self._last_executed = q
#     320         self._clear_result()
# --> 321         conn.query(q)
#     322         self._do_get_result()
#     323         return self.rowcount
#
# ~\anaconda3\envs\study\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
# ...

# %%
sql = """
insert into scores values ('Lee',90,80,100)
"""
cursor.execute(sql)
db.commit()

# %%
sql = 'delete from scores where name = "Jay"'
sql = 'delete from scores where name = "Lee"'
cursor.execute(sql)
db.commit()

# %%
db.close()

# %%
db = pymysql.connect(host='127.0.0.1',port=3306,user='jay',passwd='12345',db='w3schools',charset='utf8')

# %%
sql = '''
CREATE TABLE scores2(
    name nvarchar(20) NOT NULL,
    math int,
    science int,
    english int,
    PRIMARY KEY (name)
    )
'''
cursor.execute(sql)
db.commit()

# %%
cursor = db.cursor()

# %%
sql = """
insert into scores2 values ('홍길동',90,80,100)
"""
cursor.execute(sql)
db.commit()

# %%
sql = 'delete from scores2 where name = "홍길동"'
cursor.execute(sql)
db.commit()

# %%
db.close()

# %%
#실습 01

db = pymysql.connect(host='127.0.0.1',port=3306,user='jay',passwd='12345',db='w3schools',charset='utf8')
cursor = db.cursor()

while True:
    menu = input('메뉴를 선택해주세요 (1-입력,2-조회,3-삭제,0-종료):')
    if int(menu) == 1: #입력
        name = input('이름:')
        math = int(input('수학:'))
        science = int(input('과학:'))
        english = int(input('영어:'))
        
        sql = f"""insert into scores3(name,math,science,english) 
                    values ('{name}','{math}','{science}','{english}')"""
        cursor.execute(sql)
        db.commit()
#         sql = """insert into scores3(name,math,science,english) 
#                     values (%s,%s,%s,%s)"""
#         cursor.execute(sql,'name','math','science','english')
#         db.commit()
        
    elif int(menu) == 2: #조회
        sql = """select * from scores3"""
        cursor.execute(sql)
        rs =cursor.fetchall()
        for r in rs:
            print("[{}] 이름: {}, 수학: {}, 과학: {}, 영어: {}".format(r[0],r[1],r[2],r[3],r[4]))
            
    elif int(menu) == 3: #삭제
        sql = """select * from scores3"""
        cursor.execute(sql)
        rs =cursor.fetchall()
        for result in rs:
            print("[{}] 이름: {}, 수학: {}, 과학: {}, 영어: {}".format(r[0],r[1],r[2],r[3],r[4]))
            
        del_num = int(input('삭제할 번호를 입력해주세요:'))
        sql = """delete from scores3 where ID=%s """
        cursor.execute(sql,del_num)
        db.commit()
        print('삭제가 완료되었습니다.')
        
    elif int(menu) == 0: #종료
        db.close()
        print('종료되었습니다.')
        break
    else:
        print('잘못된 입력입니다.')
# Out:
# 메뉴를 선택해주세요 (1-입력,2-조회,3-삭제,0-종료):3
# [4] 이름: 홍길동, 수학: 10, 과학: 20, 영어: 30
# 삭제할 번호를 입력해주세요:4
# 삭제가 완료되었습니다.
# 메뉴를 선택해주세요 (1-입력,2-조회,3-삭제,0-종료):2
# 메뉴를 선택해주세요 (1-입력,2-조회,3-삭제,0-종료):0
# 종료되었습니다.

# %% [markdown]
# #sql = 'delete from scores2'
# cursor.execute(sql)
# db.commit()

# %%
db = pymysql.connect(host='127.0.0.1',port=3306,user='jay',passwd='12345',db='w3schools',charset='utf8')

# %%
cursor = db.cursor()

# %%
sql = '''
CREATE TABLE scores3(
    ID int NOT NULL AUTO_INCREMENT,
    name nvarchar(20),
    math int,
    science int,
    english int,
    PRIMARY KEY (ID)
    )
'''
cursor.execute(sql)
db.commit()

# %%
db.close()

# %%
db = pymysql.connect(host='127.0.0.1',port=3306,user='jay',passwd='12345',db='classicmodels',charset='utf8')
cursor = db.cursor()

# %%
sql = '''
select country,count(employeenumber) from employees
inner join offices on employees.officecode = offices.officecode
group by country order by country
'''
cursor.execute(sql)
re = cursor.fetchall()
for r in re:
    print(r)
# Out:
# ('Australia', 4)
# ('France', 5)
# ('Japan', 2)
# ('UK', 2)
# ('USA', 10)

# %%
db.close()
