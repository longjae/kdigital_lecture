# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome('C:/Users/mmqq2/Downloads/chromedriver')
driver.get('https://www.jungle.co.kr/')

# %%
driver.find_elements_by_css_selector('div[class="container_main"] ul[class="thumb_list"] li span[class="title"]')[0].text
# Out:
# '시간과 공간의 제약을 넘어선 ‘미켈란젤로 특별전’'

# %%
driver = webdriver.Chrome('C:/Users/mmqq2/Downloads/chromedriver')
driver.get('https://www.hackerrank.com')
login_btn = driver.find_element_by_css_selector('#menu-item-2887 > a')
login_btn.click()

# %%
driver = webdriver.Chrome('C:/Users/mmqq2/Downloads/chromedriver')
driver.get('https://www.hackerrank.com')

login_btn = driver.find_element_by_css_selector('#menu-item-2887 > a')
login_btn.click()

#login_btn2 = driver.find_element_by_css_selector('#post-175 > div > div > div.fl-row.fl-row-full-width.fl-row-bg-none.fl-node-5bd106f71c93d.hr__header-form-section.hr__header-form-section--sign-up > div > div > div.fl-col-group.fl-node-5bd106f71c9ec.fl-col-group-custom-width > div.fl-col.fl-node-5bd106f71cd43 > div > div.fl-module.fl-module-button.fl-node-5bd106f71cbed.hr__builder-button.hr__builder-button--primary.hr__builder-button--primary--halo.hr__builder-button--lg > div > div > a')
login_btn2 = driver.find_element_by_css_selector('.fl-node-5bd106f71cd43 a.fl-button')
login_btn2.click()

input_id = driver.find_element_by_css_selector('#input-1')
input_pw = driver.find_element_by_css_selector('#input-2')

input_id.send_keys('mmqq2003@gmail.com')
input_pw.send_keys('ak150500dl!')

login_btn3 = driver.find_element_by_css_selector('#tab-1-content-1 > div.login-form.auth-form.theme-m > form > div.form-item.clearfix > button')
login_btn3.click()

# %%
driver = webdriver.Chrome('C:/Users/mmqq2/Downloads/chromedriver')
driver.get('https://www.jungle.co.kr/')
driver.implicitly_wait(5)

#스크롤 맨 아래로 내려가게함
more_btn = driver.find_element_by_css_selector('#more')
more_btn.click()

driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL = 'https://www.jungle.co.kr/'
response = requests.get(URL)
soup = BeautifulSoup(response.text,'html.parser')

li_list = soup.select('div[class="container_main"] ul li')

for li in li_list:
    title = li.select_one('span[class="title"]')
    if title:
        print(title.text)
# Out:
# 시간과 공간의 제약을 넘어선 ‘미켈란젤로 특별전’
# '싱가포르 블루'에 담긴 싱가포르의 다양성과 아름다움
# LG하우시스가 발표한 2021/22 디자인 트렌드
# 제 2회 팜(Farm)터지고 펀(Fun)한 농업농촌 영상 공모전(~ 11월 26일)
# 화성습지 23초 영화제 및 알락꼬리마도요 얼굴 찾기 공모전
# 인천 유나이티드의 마스코트 '유티 페이퍼토이’ 탄생
# 울산 울주군, ‘해뜨미’캐릭터 활동 본격화
# 신세계인터내셔날, MZ세대 맞춤형 뷰티 브랜드 ‘로이비’출시
# 하나카드, 신규 디지털 브랜드 ‘MULTI’ 출시
# 전남공예창작지원센터, 브랜드 로고 개발
# [미니인턴X팀와이퍼] 2주만에 '디자이너' 실무 역량 쌓고 채용연계까지? 미니인턴 지금 신

# %%
import time

# %%
driver = webdriver.Chrome('C:/Users/mmqq2/Downloads/chromedriver')
driver.get('https://www.jungle.co.kr/')

title = driver.find_elements_by_css_selector('span[class="title"]')

for i in range(len(title)):
    more_btn = driver.find_element_by_css_selector('#more')
    more_btn.click()

    print(i+1,title[i].text)
    time.sleep(0.5)
# Out:
# 1 시간과 공간의 제약을 넘어선 ‘미켈란젤로 특별전’
# 2 '싱가포르 블루'에 담긴 싱가포르의 다양성과 아름다움
# 3 LG하우시스가 발표한 2021/22 디자인 트렌드
# 4 inner potential : 우리 모두에게 잠재된 능력의 발견
# 5 제 2회 팜(Farm)터지고 펀(Fun)한 농업농촌 영상 공모전(~ 11월 26일)
# 6 화성습지 23초 영화제 및 알락꼬리마도요 얼굴 찾기 공모전
# 7 인천 유나이티드의 마스코트 '유티 페이퍼토이’ 탄생
# 8 울산 울주군, ‘해뜨미’캐릭터 활동 본격화
# 9 신세계인터내셔날, MZ세대 맞춤형 뷰티 브랜드 ‘로이비’출시
# 10 하나카드, 신규 디지털 브랜드 ‘MULTI’ 출시
# 11 전남공예창작지원센터, 브랜드 로고 개발
# 12 [미니인턴X팀와이퍼] 2주만에 '디자이너' 실무 역량 쌓고 채용연계까지? 미니인턴 지금 신

# %%
driver = webdriver.Chrome('C:/Users/mmqq2/Downloads/chromedriver')
driver.get('https://www.jungle.co.kr/')

i = -1
while i != -2:
    title = driver.find_elements_by_css_selector('span[class="title"]')
    more_btn = driver.find_element_by_css_selector('#more')
    more_btn.click()
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")

    print(i+1,title[i].text)
    time.sleep(0.5)
    i += 1
# Out:
# [미니인턴X팀와이퍼] 2주만에 '디자이너' 실무 역량 쌓고 채용연계까지? 미니인턴 지금 신
# 시간과 공간의 제약을 넘어선 ‘미켈란젤로 특별전’
# '싱가포르 블루'에 담긴 싱가포르의 다양성과 아름다움
# LG하우시스가 발표한 2021/22 디자인 트렌드
# inner potential : 우리 모두에게 잠재된 능력의 발견
# 제 2회 팜(Farm)터지고 펀(Fun)한 농업농촌 영상 공모전(~ 11월 26일)
# 화성습지 23초 영화제 및 알락꼬리마도요 얼굴 찾기 공모전
# 인천 유나이티드의 마스코트 '유티 페이퍼토이’ 탄생
# 울산 울주군, ‘해뜨미’캐릭터 활동 본격화
# 신세계인터내셔날, MZ세대 맞춤형 뷰티 브랜드 ‘로이비’출시
# 하나카드, 신규 디지털 브랜드 ‘MULTI’ 출시
# 전남공예창작지원센터, 브랜드 로고 개발
# [미니인턴X팀와이퍼] 2주만에 '디자이너' 실무 역량 쌓고 채용연계까지? 미니인턴 지금 신
# 영화 <파힘> 팬아트 공모전
# 하나의 문화로 경험하는 브랜드, 코오롱FnC
# 비대면으로 만나는 연말연시 콘텐츠 세 가지
# 광주시, ‘5·18민주화운동’의 정체성과 상징 담은 엠블럼 공개
# 인천시교육청, 2021 슬로건 ‘인천을 품고 세계로, 우리인천교육’ 선정
# 영화진흥위원회, ‘코픽’으로 새로운 CI 선보여
# 괴산군, 친환경 인증 쌀 ‘괴산순정농부 쌀’ 포장재 디자인 공개
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-125-edebe7485197> in <module>
#      10
#      11     print(title[i].text)
# ---> 12     time.sleep(0.5)
#      13     i += 1
#
# ...

# %%
driver = webdriver.Chrome('C:/Users/mmqq2/Downloads/chromedriver')
driver.get('https://www.jungle.co.kr/')
ti_list=driver.find_elements_by_css_selector("ul.thumb_list span.title")
#megazine=driver.find_elements_by_css_selector("ul.thumb_list span.thumb_cate")
i=0
n=0
while i<len(ti_list):
    while n < len(ti_list)-1:
        print(ti_list[n].text)
        n+=1
    more_btn=driver.find_element_by_css_selector("#more")
    more_btn.click()
    ti_list=driver.find_elements_by_css_selector("ul.thumb_list span.title")
    i=n
# Out:
# 시간과 공간의 제약을 넘어선 ‘미켈란젤로 특별전’
# '싱가포르 블루'에 담긴 싱가포르의 다양성과 아름다움
# LG하우시스가 발표한 2021/22 디자인 트렌드
# inner potential : 우리 모두에게 잠재된 능력의 발견
# 제 2회 팜(Farm)터지고 펀(Fun)한 농업농촌 영상 공모전(~ 11월 26일)
# 화성습지 23초 영화제 및 알락꼬리마도요 얼굴 찾기 공모전
# 인천 유나이티드의 마스코트 '유티 페이퍼토이’ 탄생
# 울산 울주군, ‘해뜨미’캐릭터 활동 본격화
# 신세계인터내셔날, MZ세대 맞춤형 뷰티 브랜드 ‘로이비’출시
# 하나카드, 신규 디지털 브랜드 ‘MULTI’ 출시
# 전남공예창작지원센터, 브랜드 로고 개발
# [미니인턴X팀와이퍼] 2주만에 '디자이너' 실무 역량 쌓고 채용연계까지? 미니인턴 지금 신
# 영화 <파힘> 팬아트 공모전
# 하나의 문화로 경험하는 브랜드, 코오롱FnC
# 비대면으로 만나는 연말연시 콘텐츠 세 가지
# 광주시, ‘5·18민주화운동’의 정체성과 상징 담은 엠블럼 공개
# 인천시교육청, 2021 슬로건 ‘인천을 품고 세계로, 우리인천교육’ 선정
# 영화진흥위원회, ‘코픽’으로 새로운 CI 선보여
# 영화 <파힘> 팬아트 공모전
# 하나의 문화로 경험하는 브랜드, 코오롱FnC
# 비대면으로 만나는 연말연시 콘텐츠 세 가지
# 광주시, ‘5·18민주화운동’의 정체성과 상징 담은 엠블럼 공개
# 인천시교육청, 2021 슬로건 ‘인천을 품고 세계로, 우리인천교육’ 선정
# 영화진흥위원회, ‘코픽’으로 새로운 CI 선보여
# 괴산군, 친환경 인증 쌀 ‘괴산순정농부 쌀’ 포장재 디자인 공개
# SK 그룹 CI ‘행복날개’ 다양한 색상·디자인으로 업그레이드
# 야나두 힘나쏭 챌린지 시즌2
# 동북아역사재단 독도체험관 확장 이전 아이디어 제안 공모전
# 위트와 에너지 전하는 슈퍼스타 할머니 아티스트 로즈 와일리
# ‘산타세종’ 코로나 극복 기원 이모티콘 공개...성탄절 무료 배포
# ...

# %%
URL = 'http://openapi.epost.go.kr/postal/retrieveNewAdressAreaCdService/retrieveNewAdressAreaCdService/getNewAddressListAreaCd'
service_key = '7yWPPwS8zmV0DnBUHwcRWXXW5meuEdwnEP17%2BHE8cABq0DwqKFh7Vx49rXj%2FFg4joJzf%2FLctEkB0Ui7wZ7ruAA%3D%3D'
service_key_decoded = requests.utils.unquote(service_key)
print(service_key_decoded)
# Out:
# 7yWPPwS8zmV0DnBUHwcRWXXW5meuEdwnEP17+HE8cABq0DwqKFh7Vx49rXj/Fg4joJzf/LctEkB0Ui7wZ7ruAA==

# %%
req_parameter = {"ServiceKey":service_key_decoded, "searchSe":"road","srchwrd":"반포대로 201"}
result = requests.get(URL, params=req_parameter)
print(result.text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><NewAddressListResponse><cmmMsgHeader><requestMsgId></requestMsgId><responseMsgId></responseMsgId><responseTime>20201228:150857224</responseTime><successYN>Y</successYN><returnCode>00</returnCode><errMsg></errMsg><totalCount>1</totalCount><countPerPage>10</countPerPage><totalPage>1</totalPage><currentPage></currentPage></cmmMsgHeader><newAddressListAreaCd><zipNo>06579</zipNo><lnmAdres>서울특별시 서초구 반포대로 201 (반포동, 국립중앙도서관)</lnmAdres><rnAdres>서울특별시 서초구 반포동 산60-1 국립중앙도서관</rnAdres></newAddressListAreaCd></NewAddressListResponse>

# %%
URL = 'http://openapi.epost.go.kr/postal/retrieveNewAdressAreaCdService/retrieveNewAdressAreaCdService/getNewAddressListAreaCd?ServiceKey=7yWPPwS8zmV0DnBUHwcRWXXW5meuEdwnEP17%2BHE8cABq0DwqKFh7Vx49rXj%2FFg4joJzf%2FLctEkB0Ui7wZ7ruAA%3D%3D&searchSe=road&srchwrd=세종로 17'
result = requests.get(URL)
print(result.text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><NewAddressListResponse><cmmMsgHeader><requestMsgId></requestMsgId><responseMsgId></responseMsgId><responseTime>20201228:15204860</responseTime><successYN>Y</successYN><returnCode>00</returnCode><errMsg></errMsg><totalCount>2</totalCount><countPerPage>10</countPerPage><totalPage>1</totalPage><currentPage></currentPage></cmmMsgHeader><newAddressListAreaCd><zipNo>12621</zipNo><lnmAdres>경기도 여주시 세종로 17 (홍문동)</lnmAdres><rnAdres>경기도 여주시 홍문동 111-15</rnAdres></newAddressListAreaCd><newAddressListAreaCd><zipNo>12621</zipNo><lnmAdres>경기도 여주시 세종로 17-1 (홍문동)</lnmAdres><rnAdres>경기도 여주시 홍문동 111-2</rnAdres></newAddressListAreaCd></NewAddressListResponse>

# %%
# !pip install xmltodict

# %%
import xmltodict
dict_data = xmltodict.parse(result.text)
dict_data
# Out:
# OrderedDict([('NewAddressListResponse',
#               OrderedDict([('cmmMsgHeader',
#                             OrderedDict([('requestMsgId', None),
#                                          ('responseMsgId', None),
#                                          ('responseTime',
#                                           '20201228:150224904'),
#                                          ('successYN', 'Y'),
#                                          ('returnCode', '00'),
#                                          ('errMsg', None),
#                                          ('totalCount', '1'),
#                                          ('countPerPage', '10'),
#                                          ('totalPage', '1'),
#                                          ('currentPage', None)])),
#                            ('newAddressListAreaCd',
#                             OrderedDict([('zipNo', '06579'),
#                                          ('lnmAdres',
# ...

# %%
dict_data['NewAddressListResponse']['newAddressListAreaCd']['zipNo']
# Out:
# '06579'

# %%
URL = 'https://www.rocketpunch.com/jobs?page=1'
driver = webdriver.Chrome('C:/Users/mmqq2/Downloads/chromedriver')
driver.get(URL)

result = []
i=1
while i != 11:
    
    name = driver.find_elements_by_css_selector('#company-list div[class="company-name"] h4')
    desc = driver.find_elements_by_css_selector('#company-list div[class="description"]')
    job_detail = driver.find_elements_by_css_selector('#company-list div[class="job-detail"] a[target="_blank"]')
    
    
#     for i in range(len(name)):
#         com_list = {}
#         com_list['name'] = name[i].text
#         com_list['description'] = desc[i].text
#         result.append(com_list)
        
#     print(result)
    next_page = driver.find_element_by_css_selector('#search-results > div.ui.blank.right.floated.segment > div > a:nth-child(4)')
    next_page.click()
    
    i += 1
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-196-55ba45faae30> in <module>
#      19
#      20 #     print(result)
# ---> 21     next_page = driver.find_element_by_css_selector('#search-results > div.ui.blank.right.floated.segment > div > a:nth-child(4)')
#      22     next_page.click()
#      23
#
# ~\anaconda3\envs\study\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# ~\anaconda3\envs\study\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
# ...

# %%
URL = 'https://www.rocketpunch.com/jobs?page=1'
driver = webdriver.Chrome('C:/Users/mmqq2/Downloads/chromedriver')
driver.get(URL)

c_list=driver.find_elements_by_css_selector("#company-list")
n_list=driver.find_elements_by_css_selector("#company-list .company-name strong")
d_list=driver.find_elements_by_css_selector("#company-list .description")
#dt_list=driver.find_elements_by_css_selector("#company-list .job_detail .nowrap")

# print(n_list[0].text)

ro_list=[]
for i,v in enumerate(n_list):
    ro_dict={"name":n_list[i].text,"description":d_list[i].text} #,"detail":dt_list[i].text
    ro_list.append(ro_dict)
ro_list
# Out:
# []
